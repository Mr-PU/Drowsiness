# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\prashant\anaconda3\lib\site-packages (9.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import load_model
import cv2
from PIL import Image

# %%
import numpy as np

# %%
model = load_model('drowiness.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 78, 78, 256)       7168
#
#  max_pooling2d (MaxPooling2D  (None, 39, 39, 256)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 128)       295040
#
#  max_pooling2d_1 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        73792
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 32)          18464
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 288)               0
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 64)                18496
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 413,220
# Trainable params: 413,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
#img= "https://image.cnbcfm.com/api/v1/image/104995503-rsz_gettyimages-556453489.jpg?v=1532563687&w=740&h=416&ffmt=webp&vtcrop=y"

# %%
Image.open("121.jpg")
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=740x416>

# %%
image_size = (80, 80)

# %%
img = Image.open("121.jpg").resize(image_size)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=80x80>

# %%
img = np.array(img)/255.0

# %%
img.shape
# Out:
# (80, 80, 3)

# %%
#img = img[np.newaxis,...]

# %%
#img[np.newaxis,...].shape

# %%
result = model.predict(img[np.newaxis, ...])
# Out:
# 1/1 [==============================] - 0s 245ms/step

# %%
result.shape
# Out:
# (1, 4)

# %%
result
# Out:
# array([[1.01057374e-07, 5.65677357e-04, 7.78564215e-02, 9.21577871e-01]],
#       dtype=float32)

# %%
predicted_label_index = np.argmax(result)

# %%
#'Closed', 'no_yawn', 'Open', 'yawn'

# %%
if (predicted_label_index==0) & (predicted_label_index==3):
    print('Drowsiness Detected')

elif (predicted_label_index==3):
    print('Drowsiness Detected')

elif predicted_label_index==2 & (predicted_label_index==3):
    print('Drowsiness Detected')

elif (predicted_label_index==1) & (predicted_label_index==2):
    print('No Drowsiness Detected')
    
elif predicted_label_index==1:
    print('No Drowsiness Detected')
# Out:
# Drowsiness Detected
